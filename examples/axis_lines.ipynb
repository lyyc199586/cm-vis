# %%
## test axis lines
import numpy as np
import matplotlib.pyplot as plt
from cm_vis.utils.axis import axis_line

x = np.array([1, 2, 3, 4, 5])
y = x**2


plt.style.use("elsevier")
fig, ax = plt.subplots()

ax.plot(x, y)

axis_line(ax, origin=[0, 0])

# %%
## try another origin
import numpy as np
import matplotlib.pyplot as plt
from cm_vis.utils.axis import axis_line

x = np.array([1, 2, 3, 4, 5])
y = x**2


plt.style.use("elsevier")
fig, ax = plt.subplots()

ax.plot(x, y)

axis_line(ax, origin=[2.5, 14])
